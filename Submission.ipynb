# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv("New_Dataset/NCG_sentences.csv")

# %%
# !mkdir submission

# %%
cd submission
# Out:
# /home/ammaar/Desktop/TaskA/submission

# %%
#df = df[df['labels'] == 1]

# %%
df
# Out:
#                            topic  paper_ID  \
# 0           constituency_parsing         0
# 1           constituency_parsing         0
# 2           constituency_parsing         0
# 3           constituency_parsing         0
# 4           constituency_parsing         0
# ...                          ...       ...
# 3201  natural_language_inference         9
# 3202  natural_language_inference         9
# 3203  natural_language_inference         9
# 3204  natural_language_inference         9
# 3205  natural_language_inference         9
#
#                                                    text  main_heading  \
# 0                     Recurrent Neural Network Grammars         title
# 1     In this paper , we introduce recurrent neural ...  introduction
# 2     RNNGs operate via a recursive syntactic proces...  introduction
# 3     The foundation of this work is a top - down va...  introduction
# 4     We give two variants of the algorithm , one fo...  introduction
# ...                                                 ...           ...
# 3201  We then further finetuned the model on the tra...    experiment
# 3202  We trained the model by minimizing loss L from...    experiment
# 3203  Evaluation completed in about 5 hours on the N...    experiment
# 3204  Our BERT model for NQ performs dramatically be...    experiment
# 3205  Our model closes the gap between the F 1 score...    experiment
#
#        sub_heading  pos1  pos2  pos3      ofs1      ofs2      ofs3  length
# 0            title     2     1     1  0.008969  1.000000  1.000000       4
# 1     introduction    12     5     5  0.053812  0.238095  0.238095      29
# 2     introduction    13     6     6  0.058296  0.285714  0.285714      35
# 3     introduction    14     7     7  0.062780  0.333333  0.333333      16
# 4     introduction    15     8     8  0.067265  0.380952  0.380952      24
# ...            ...   ...   ...   ...       ...       ...       ...     ...
# 3201   Experiments    55     3     3  0.846154  0.300000  0.300000      17
# 3202   Experiments    56     4     4  0.861538  0.400000  0.400000      26
# 3203   Experiments    58     6     6  0.892308  0.600000  0.600000      20
# 3204   Experiments    60     8     8  0.923077  0.800000  0.800000      18
# 3205   Experiments    61     9     9  0.938462  0.900000  0.900000      40
#
# [3206 rows x 12 columns]

# %%
series = df.groupby(['topic', 'paper_ID']).size().reset_index().rename(columns={0:'count'})

# %%
series[0:15]
# Out:
#                      topic  paper_ID  count
# 0     constituency_parsing         0     13
# 1     constituency_parsing         1     16
# 2     constituency_parsing         2      9
# 3     constituency_parsing         3     21
# 4     constituency_parsing         4      9
# 5     constituency_parsing         5     15
# 6     constituency_parsing         6      8
# 7     constituency_parsing         7      7
# 8     constituency_parsing         8     14
# 9   coreference_resolution         0     15
# 10  coreference_resolution         1     20
# 11  coreference_resolution         2      8
# 12  coreference_resolution         3     16
# 13  coreference_resolution         4     32
# 14  coreference_resolution         5     22

# %%
task = ""

# %%
topics = series['topic'].to_list()
papers = series['paper_ID'].to_list()

# %%
l = len(topics)
for i in range(l):
    topic = topics[i]
    num = papers[i]
    if(topic == task):
        # !mkdir $num
    else:
        if(task != ""):
            os.chdir("..")
        task = topic
        # !mkdir $topic
        os.chdir(topic)
        # !mkdir $num

# %%
series[150:155]
# Out:
#                           topic  paper_ID  count
# 150  natural_language_inference        27     22
# 151  natural_language_inference        28     28
# 152  natural_language_inference        29     14
# 153  natural_language_inference        30     26
# 154  natural_language_inference        31     23

# %%
# !pwd
# Out:
# /home/ammaar/Desktop/TaskA/submission/natural_language_inference

# %%
os.chdir("..")

# %%
topics = df['topic'].to_list()
papers = df['paper_ID'].to_list()
sent = df['pos1'].to_list()

# %%
task = topics[0]
pid = papers[0]
l = len(topics)
sentences = []
for i in range(l):
    topic = topics[i]
    paper = papers[i]
    if(topic == task and paper == pid) or (i==0):
        sentences.append(sent[i])
    else:
        path = task + "/" + str(pid) + "/sentences.txt"
        with open(path, mode='wt', encoding='utf-8') as file:
            for x in sentences:
                file.write("%i\n" % x)
        task = topic
        pid = paper
        sentences = [sent[i]]

# %%
pid
# Out:
# 9

# %%
path = task + "/" + str(pid) + "/sentences.txt"
with open(path, mode='wt', encoding='utf-8') as file:
    for x in sentences:
        file.write("%i\n" % x)

# %%
l = len(topics)
for i in range(l):
    topic = topics[i]
    paper = papers[i]
    path = topic + "/" + str(paper)
    filepath = os.path.join(path, 'entities.txt')
    f = open(filepath, "w")
    f.close()
    dir_path = os.path.join(path, 'triples')
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
